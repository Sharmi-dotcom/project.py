# %%
name="Sharmi"

age=20

CGPA=8.5

placed=False

print(" Student Name:", name)

print(" Age:", age)

print(" CGPA:", CGPA)

print(" Placed:",placed)

print(type(name))

print(type(age))

print(type(CGPA))

print(type(placed))

print(len(name))
# Out:
#  Student Name: Sharmi
#  Age: 20
#  CGPA: 8.5
#  Placed: False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 6
