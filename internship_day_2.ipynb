# %%
list

name=["Sharmi","Pooja","Jai","Sri"]
name.append("Bavani")
marks=[50,40,80,90]
print(name)
print(marks[2])
print(len(name))
print(len(marks))

tuple

days=("Monday","Tuesday","Wednesday","Thursday")
print(days[1])

dict

student={
    "name":"Sharmi",
    "age":19
}
# Out:
# ['Sharmi', 'Pooja', 'Jai', 'Sri', 'Bavani']
# 80
# 5
# 4
# Tuesday
